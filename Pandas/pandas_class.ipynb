# %% [markdown]
# 25/ 08/ 26

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# aext-assistant                    4.20.0
# aext-assistant-server             4.20.0
# aext-core                         4.20.0
# aext-core-server                  4.20.0
# aext_environments_server          4.20.0
# aext-panels                       4.20.0
# aext-panels-server                4.20.0
# aext-project-filebrowser-server   4.20.0
# aext-share-notebook               4.20.0
# aext-share-notebook-server        4.20.0
# aext-shared                       4.20.0
# aext-toolbox                      4.20.0
# aiobotocore                       2.25.0
# aiodns                            3.5.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.13.2
# aioitertools                      0.12.0
# aiosignal                         1.4.0
# alabaster                         0.7.16
# alembic                           1.18.4
# altair                            5.5.0
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
# %pdoc pd
# Out:
# Class docstring:
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
#         higher dimensional objects
# ...

# %%
data = [1, 2, 3, 4, 7, 77]
s = pd.Series(data)

s
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5    77
# dtype: int64

# %%
s.values
# Out:
# array([ 1,  2,  3,  4,  7, 77])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# let's create a Series with an index identifying each data point with a label

data = [x * 10 for x in range(5)]

s = pd.Series(data, index=['a', 'b', 'c', 'e', 'f'])

s
# Out:
# a     0
# b    10
# c    20
# e    30
# f    40
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'e', 'f'], dtype='object')

# %%
# s[3]
s.iloc[3] # integer location
# Out:
# np.int64(30)

# %%
s[:3]
# Out:
# a     0
# b    10
# c    20
# dtype: int64

# %%
# By label dict
s ['a']
# Out:
# np.int64(0)

# %%
# to select multiple rowa or elements, use a list of labels

s[['a', 'e']]
# Out:
# a     0
# e    30
# dtype: int64

# %%
# Using .loc and .iloc
# Note: loc selects data using row and column names (labels),
# while iloc uses number positions (integers from 0 to n-1).
# When you slice a range, loc includes the last item, but iloc stops before the last item
# Label-based
print(s.loc['b'])
# Out:
# 10

# %%
# Position -based 

print(s.iloc[1])
# Out:
# 10

# %%
s[4] = 50
# Out:
# /var/folders/r5/4k_jrps502s1wr2pyxpkh6dw0000gn/T/ipykernel_85578/3410906351.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   s[4] = 50

# %%
s
# Out:
# a     0
# b    10
# c    20
# e    30
# f    50
# dtype: int64

# %%
# Series operation
s+5
# Out:
# a     5
# b    15
# c    25
# e    35
# f    55
# dtype: int64

# %%
s*2
# Out:
# a      0
# b     20
# c     40
# e     60
# f    100
# dtype: int64

# %%
# Bolean operation

s > 10
# Out:
# a    False
# b    False
# c     True
# e     True
# f     True
# dtype: bool

# %%
# filtering with condition
s[s > 15]
# Out:
# c    20
# e    30
# f    50
# dtype: int64

# %% [markdown]
# Another way to think about a Series is as a fixed-length, ordered dict, as it is a
# mapping of index values to data values. It can be used in many contexts where
# you might use a dict:

# %%
'b' in s    # membership
# Out:
# True

# %%
# You can also create a series from a dictionary
# Note: if you pass a list, pd assigns it index (or you assign your index
# but if you pass a dict, pd uses the key as index (label).
sdata = {
'Kwara': 'Ilorin',
'Ondo': 'Akure',
'Lagos': 'Ikeja',
'Oyo': 'Ibadan'
}
s2 = pd.Series(sdata)
s
# Out:
# a     0
# b    10
# c    20
# e    30
# f    50
# dtype: int64

# %%
Handling Missing Data (None or np.nan)

s.is

# %% [markdown]
# ## Name Attribute and Index Manipulation

# %%
s.name

# %%
s.name = 'test data'

# %%
s.name
# Out:
# 'test data'

# %%
# Setting or changing index

s.index = ['x', 'y', 'z', 'w', 'v']

s.index
# Out:
# Index(['x', 'y', 'z', 'w', 'v'], dtype='object')

# %%
s
# Out:
# x     0
# y    10
# z    20
# w    30
# v    50
# Name: test data, dtype: int64

# %%
# Resetting index 

s = s.reset_index(drop=True)

# %% [markdown]
# ## DataFrame (2D)

# %% [markdown]
# Each column is essentially a Series.
# Supports row and column indexing.
# Offers powerful grouping, filtering, aggregation, reshaping, and merging
# capabilities.

# %%
data = {
    'Name': ['Hannah', 'Zainab', 'Tomi', 'Funmi'],
    'Age': [15, 20, 18, 25],
    'City': ['Ilorin', 'Lagos', 'Ibadan', 'Abuja']
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age    City
# 0  Hannah   15  Ilorin
# 1  Zainab   20   Lagos
# 2    Tomi   18  Ibadan
# 3   Funmi   25   Abuja

# %%
index =['one', 'two', 'three', 'four']
df = pd.DataFrame(data, index=index)
df
# Out:
#          Name  Age    City
# one    Hannah   15  Ilorin
# two    Zainab   20   Lagos
# three    Tomi   18  Ibadan
# four    Funmi   25   Abuja

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df ['Name']     # check what happen here
# Out:
# one      Hannah
# two      Zainab
# three      Tomi
# four      Funmi
# Name: Name, dtype: object

# %%
# Please, Note: df[column name] works for any column name,
# but df.column only works when the column name is a valid Python variabl
df.Age

# %%
data = {
'Name': ['Adeola', 'Arafat', 'Nofi', 'Salamat'],
'Age': [25, 30, 35, 10],
'City': ['Ilorin', 'Lagos', 'Ibadan', 'Abuja']
}
df = pd.DataFrame(data)
df
# Note: When you are assigning lists or arrays to a column, the value’s length must match the length of the DataFrame.
# Out:
#       Name  Age    City
# 0   Adeola   25  Ilorin
# 1   Arafat   30   Lagos
# 2     Nofi   35  Ibadan
# 3  Salamat   10   Abuja

# %%
df.T
# Out:
#            0       1       2        3
# Name  Adeola  Arafat    Nofi  Salamat
# Age       25      30      35       10
# City  Ilorin   Lagos  Ibadan    Abuja

# %%
# Row with label/index
df.loc[0]
# Out:
# Survived                         0
# Pclass                           3
# Name        Mr. Owen Harris Braund
# Sex                           male
# Age                           22.0
# SibSp                            1
# PaCh                             0
# Fare                          7.25
# Name: 0, dtype: object

# %%
# selecting by condition

df[df['Age'] > 60 ]
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 33          0       2                      Mr. Edward H Wheadon    male  66.0
# 53          0       1             Mr. Engelhart Cornelius Ostby    male  65.0
# 63          0       1                      Mr. Albert A Stewart    male  64.0
# 95          0       1                  Mr. George B Goldschmidt    male  71.0
# 115         0       3                       Mr. Patrick Connors    male  70.5
# 169         0       1                  Mr. Wyckoff Van der hoef    male  61.0
# 251         0       1                  Mr. William Thomas Stead    male  62.0
# 273         1       1          Miss. Kornelia Theodosia Andrews  female  63.0
# 278         0       3                           Mr. Frank Duane    male  65.0
# 324         0       3                  Mr. Johan Hansen Nysveen    male  61.0
# 435         0       1                          Mr. Mark Fortune    male  64.0
# ...

# %%
# Mixed selection
# format: df.loc[row_indexer, column_indexer]

df.loc[0, 'Name']
# Out:
# 'Mr. Owen Harris Braund'

# %%
df.iloc [0, 2] # remember: col
# Out:
# 'Mr. Owen Harris Braund'

# %%
# Rows from index 0 to 2 (inclusive)

df.loc[0:2]
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  26.0      0     0   7.9250

# %%
# All rows, selected columns

df.loc[:, ['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                               Mr. Owen Harris Braund  22.0
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0
# 2                                Miss. Laina Heikkinen  26.0
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0
# 4                              Mr. William Henry Allen  35.0
# ..                                                 ...   ...
# 882                               Rev. Juozas Montvila  27.0
# 883                        Miss. Margaret Edith Graham  19.0
# 884                     Miss. Catherine Helen Johnston   7.0
# 885                               Mr. Karl Howell Behr  26.0
# 886                                 Mr. Patrick Dooley  32.0
#
# [887 rows x 2 columns]

# %%
# selecting based on condition     31/08/26

df[df['Age'] > 60]
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 33          0       2                      Mr. Edward H Wheadon    male  66.0
# 53          0       1             Mr. Engelhart Cornelius Ostby    male  65.0
# 63          0       1                      Mr. Albert A Stewart    male  64.0
# 95          0       1                  Mr. George B Goldschmidt    male  71.0
# 115         0       3                       Mr. Patrick Connors    male  70.5
# 169         0       1                  Mr. Wyckoff Van der hoef    male  61.0
# 251         0       1                  Mr. William Thomas Stead    male  62.0
# 273         1       1          Miss. Kornelia Theodosia Andrews  female  63.0
# 278         0       3                           Mr. Frank Duane    male  65.0
# 324         0       3                  Mr. Johan Hansen Nysveen    male  61.0
# 435         0       1                          Mr. Mark Fortune    male  64.0
# ...

# %%
# Mixed selection
# Format: df. loc[row_indexer, column_indexer]

df.loc[0, 'Name']
# Out:
# 'Mr. Owen Harris Braund'

# %%
df.iloc[0, 2] # remember: cols are also indexed
# Out:
# 'Mr. Owen Harris Braund'

# %%
# All rows, selected columns

df.loc[:, ['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                               Mr. Owen Harris Braund  22.0
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0
# 2                                Miss. Laina Heikkinen  26.0
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0
# 4                              Mr. William Henry Allen  35.0
# ..                                                 ...   ...
# 882                               Rev. Juozas Montvila  27.0
# 883                        Miss. Margaret Edith Graham  19.0
# 884                     Miss. Catherine Helen Johnston   7.0
# 885                               Mr. Karl Howell Behr  26.0
# 886                                 Mr. Patrick Dooley  32.0
#
# [887 rows x 2 columns]

# %%
# Names where Age > 30

df.loc[df['Age'] > 30, 'Name']
# Out:
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 3            Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4                                Mr. William Henry Allen
# 6                                 Mr. Timothy J McCarthy
# 11                               Miss. Elizabeth Bonnell
#                              ...
# 869                           Mr. Victor Vander Cruyssen
# 875         Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 877                                    Mr. Johann Markun
# 881                  Mrs. William (Margaret Norton) Rice
# 886                                   Mr. Patrick Dooley
# Name: Name, Length: 362, dtype: object

# %%
df.loc[df['Age'] > 60, 'Sex']
# Out:
# 33       male
# 53       male
# 63       male
# 95       male
# 115      male
# 169      male
# 251      male
# 273    female
# 278      male
# 324      male
# 435      male
# 453      male
# 480    female
# 490      male
# 508      male
# 535      male
# 542      male
# 552      male
# 561    female
# 567      male
# 622      male
# 627      male
# 669      male
# 741      male
# 825    female
# 847      male
# Name: Sex, dtype: object

# %%
# Quick task, return name and age of those >= 70

# %%
df.loc[df['Age'] > 70, ['Name','Age']]
# Out:
#                                     Name   Age
# 95              Mr. George B Goldschmidt  71.0
# 115                  Mr. Patrick Connors  70.5
# 490               Mr. Ramon Artagaveytia  71.0
# 627  Mr. Algernon Henry Wilson Barkworth  80.0
# 847                   Mr. Johan Svensson  74.0

# %% [markdown]
# ## Basic Operation

# %%
# Filtering

# Simple condition
df[df['Fare'] > 250]
# Out:
#      Survived  Pclass                               Name     Sex   Age  SibSp  \
# 27          0       1      Mr. Charles Alexander Fortune    male  19.0      3
# 87          1       1          Miss. Mabel Helen Fortune  female  23.0      3
# 257         1       1                    Miss. Anna Ward  female  35.0      0
# 309         1       1          Miss. Emily Borie Ryerson  female  18.0      2
# 339         1       1      Miss. Alice Elizabeth Fortune  female  24.0      3
# 435         0       1                   Mr. Mark Fortune    male  64.0      1
# 676         1       1  Mr. Thomas Drake Martinez Cardeza    male  36.0      0
# 733         1       1              Mr. Gustave J Lesurer    male  35.0      0
# 738         1       1         Miss. Susan Parker Ryerson  female  21.0      2
#
#      PaCh      Fare
# 27      2  263.0000
# 87      2  263.0000
# 257     0  512.3292
# 309     2  262.3750
# 339     2  263.0000
# 435     4  263.0000
# 676     1  512.3292
# ...

# %%
# Combined/multiple conditions

# try or aswell

# %%
df[(df['Age'] > 25) & (df['Fare'] > 250)]
# Out:
#      Survived  Pclass                               Name     Sex   Age  SibSp  \
# 257         1       1                    Miss. Anna Ward  female  35.0      0
# 435         0       1                   Mr. Mark Fortune    male  64.0      1
# 676         1       1  Mr. Thomas Drake Martinez Cardeza    male  36.0      0
# 733         1       1              Mr. Gustave J Lesurer    male  35.0      0
#
#      PaCh      Fare
# 257     0  512.3292
# 435     4  263.0000
# 676     1  512.3292
# 733     0  512.3292

# %%
df[(df['Age'] > 25) | (df['Fare'] > 250)]   # or |
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# ..        ...     ...                                                ...
# 879         0       2                       Mr. Frederick James Banfield
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 882         0       2                               Rev. Juozas Montvila
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  SibSp  PaCh     Fare
# 1    female  38.0      1     0  71.2833
# ...

# %%
# String condition

df[df['Name'].str.contains('Rose')]
# Out:
#      Survived  Pclass                       Name     Sex   Age  SibSp  PaCh  \
# 851         1       3  Mrs. Sam (Leah Rosen) Aks  female  18.0      0     1
#
#      Fare
# 851  9.35

# %%
# String condition
df[df['Name'].str.contains('Arafat')]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, PaCh, Fare]
# Index: []

# %%
# class task
# select all where sex=female and survived=0

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 0)]
# Out:
#      Survived  Pclass                                               Name  \
# 14          0       3                Miss. Hulda Amanda Adolfina Vestrom
# 18          0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# 24          0       3                       Miss. Torborg Danira Palsson
# 38          0       3                  Miss. Augusta Maria Vander Planke
# 40          0       3      Mrs. Johan (Johanna Persdotter Larsson) Ahlin
# ..        ...     ...                                                ...
# 850         0       2       Mrs. Ernest Courtenay (Lilian Hughes) Carter
# 859         0       3                           Miss. Dorothy Edith Sage
# 878         0       3                        Miss. Gerda Ulrika Dahlberg
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 884         0       3                     Miss. Catherine Helen Johnston
#
#         Sex   Age  SibSp  PaCh     Fare
# 14   female  14.0      0     0   7.8542
# ...

# %% [markdown]
# Setting and Resetting Indexes

# %%
# Set a column as index
df.set_index('Name', inplace=True)       # how do i make a copy

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mr. Owen Harris Braund                                     0       3    male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1  female
# Miss. Laina Heikkinen                                      1       3  female
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1       1  female
# Mr. William Henry Allen                                    0       3    male
#
#                                                      Age  SibSp  PaCh     Fare
# Name
# Mr. Owen Harris Braund                              22.0      1     0   7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  38.0      1     0  71.2833
# Miss. Laina Heikkinen                               26.0      0     0   7.9250
# Mrs. Jacques Heath (Lily May Peel) Futrelle         35.0      1     0  53.1000
# Mr. William Henry Allen                             35.0      0     0   8.0500

# %%
df.set_index('Name', inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r5/4k_jrps502s1wr2pyxpkh6dw0000gn/T/ipykernel_85578/406395903.py in ?()
# ----> 1 df.set_index('Name', inplace=False)
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Name'] are in the columns"

# %%
# Reset index back to default
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                             Mr. Owen Harris Braund         0       3
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...         1       1
# 2                              Miss. Laina Heikkinen         1       3
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle         1       1
# 4                            Mr. William Henry Allen         0       3
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  26.0      0     0   7.9250
# 3  female  35.0      1     0  53.1000
# 4    male  35.0      0     0   8.0500

# %%
# Querying DataFrames with df.query(): More readable way to filter rows u
# Age > 30
df.query('Age > 30')

# %%
df[df['Age > 30')   # check how to run dis with multipes lines of codes

# %%
# Combined conditions
df.query("Age > 70 and Sex == 'male'")
# Out:
#                                     Name  Survived  Pclass   Sex   Age  SibSp  \
# 95              Mr. George B Goldschmidt         0       1  male  71.0      0
# 115                  Mr. Patrick Connors         0       3  male  70.5      0
# 490               Mr. Ramon Artagaveytia         0       1  male  71.0      0
# 627  Mr. Algernon Henry Wilson Barkworth         1       1  male  80.0      0
# 847                   Mr. Johan Svensson         0       3  male  74.0      0
#
#      PaCh     Fare
# 95      0  34.6542
# 115     0   7.7500
# 490     0  49.5042
# 627     0  30.0000
# 847     0   7.7750

# %%
# String match
df.query('Name == "Mr. Johan Svensson"')
# Out:
#                    Name  Survived  Pclass   Sex   Age  SibSp  PaCh   Fare
# 847  Mr. Johan Svensson         0       3  male  74.0      0     0  7.775

# %% [markdown]
#  ## Sorting

# %%
# Out:
#                    Name  Survived  Pclass   Sex   Age  SibSp  PaCh   Fare
# 847  Mr. Johan Svensson         0       3  male  74.0      0     0  7.775

# %%
## Sort by a column
df.sort_values(by='Age')
# Out:
#                                     Name  Survived  Pclass     Sex    Age  \
# 799       Master. Assad Alexander Thomas         1       3    male   0.42
# 751             Master. Viljo Hamalainen         1       2    male   0.67
# 641                Miss. Eugenie Baclini         1       3  female   0.75
# 466         Miss. Helene Barbara Baclini         1       3  female   0.75
# 827       Master. George Sibley Richards         1       2    male   0.83
# ..                                   ...       ...     ...     ...    ...
# 115                  Mr. Patrick Connors         0       3    male  70.50
# 490               Mr. Ramon Artagaveytia         0       1    male  71.00
# 95              Mr. George B Goldschmidt         0       1    male  71.00
# 847                   Mr. Johan Svensson         0       3    male  74.00
# 627  Mr. Algernon Henry Wilson Barkworth         1       1    male  80.00
#
#      SibSp  PaCh     Fare
# 799      0     1   8.5167
# ...

# %%
# Descending order
df.sort_values(by='Age', ascending=False) ['Name']
# Out:
# 627    Mr. Algernon Henry Wilson Barkworth
# 847                     Mr. Johan Svensson
# 490                 Mr. Ramon Artagaveytia
# 95                Mr. George B Goldschmidt
# 115                    Mr. Patrick Connors
#                       ...
# 77            Master. Alden Gates Caldwell
# 466           Miss. Helene Barbara Baclini
# 641                  Miss. Eugenie Baclini
# 751               Master. Viljo Hamalainen
# 799         Master. Assad Alexander Thomas
# Name: Name, Length: 887, dtype: object

# %%
# Descending order
df.sort_values(by='Age', ascending=False)
# Out:
#                                     Name  Survived  Pclass     Sex    Age  \
# 627  Mr. Algernon Henry Wilson Barkworth         1       1    male  80.00
# 847                   Mr. Johan Svensson         0       3    male  74.00
# 490               Mr. Ramon Artagaveytia         0       1    male  71.00
# 95              Mr. George B Goldschmidt         0       1    male  71.00
# 115                  Mr. Patrick Connors         0       3    male  70.50
# ..                                   ...       ...     ...     ...    ...
# 77          Master. Alden Gates Caldwell         1       2    male   0.83
# 466         Miss. Helene Barbara Baclini         1       3  female   0.75
# 641                Miss. Eugenie Baclini         1       3  female   0.75
# 751             Master. Viljo Hamalainen         1       2    male   0.67
# 799       Master. Assad Alexander Thomas         1       3    male   0.42
#
#      SibSp  PaCh     Fare
# 627      0     0  30.0000
# ...

# %%
# You can also sort by multiple columns
df.sort_values(['Age', 'Fare'])
# Note: This sorts by the Age column first. If multiple rows have the exact same age,
# the code uses the Fare column to break the tie (also in ascending order, from lowest
# Out:
#                                     Name  Survived  Pclass     Sex    Age  \
# 799       Master. Assad Alexander Thomas         1       3    male   0.42
# 751             Master. Viljo Hamalainen         1       2    male   0.67
# 466         Miss. Helene Barbara Baclini         1       3  female   0.75
# 641                Miss. Eugenie Baclini         1       3  female   0.75
# 827       Master. George Sibley Richards         1       2    male   0.83
# ..                                   ...       ...     ...     ...    ...
# 115                  Mr. Patrick Connors         0       3    male  70.50
# 95              Mr. George B Goldschmidt         0       1    male  71.00
# 490               Mr. Ramon Artagaveytia         0       1    male  71.00
# 847                   Mr. Johan Svensson         0       3    male  74.00
# 627  Mr. Algernon Henry Wilson Barkworth         1       1    male  80.00
#
#      SibSp  PaCh     Fare
# 799      0     1   8.5167
# ...

# %%
# Sort by index (the default)
df.sort_index()
# This will sort different if you used a different index like we did above
# Out:
#                                                   Name  Survived  Pclass  \
# 0                               Mr. Owen Harris Braund         0       3
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...         1       1
# 2                                Miss. Laina Heikkinen         1       3
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle         1       1
# 4                              Mr. William Henry Allen         0       3
# ..                                                 ...       ...     ...
# 882                               Rev. Juozas Montvila         0       2
# 883                        Miss. Margaret Edith Graham         1       1
# 884                     Miss. Catherine Helen Johnston         0       3
# 885                               Mr. Karl Howell Behr         1       1
# 886                                 Mr. Patrick Dooley         0       3
#
#         Sex   Age  SibSp  PaCh     Fare
# 0      male  22.0      1     0   7.2500
# ...

# %% [markdown]
# ## Grouping (groupby)

# %%
# Group by class
class_group = df.groupby('Pclass')
# This alone is not useful, unless you use operation (like .sum() or .mean() ) to performing any underlying

# %%
# Aggregate functions
# Mean Fare per class
class_group['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.707707
# Name: Fare, dtype: float64

# %%
# Total Fare per class
class_group['Fare'].sum()
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6675.6535
# Name: Fare, dtype: float64

# %%
# Aggregate functions
# Mean Fare per class
class_group['Age'].mean()
# Out:
# Pclass
# 1    38.788981
# 2    29.868641
# 3    25.188747
# Name: Age, dtype: float64

# %%
# Multiple aggregations
class_group.agg({'Fare': ['mean', 'max', 'min']})
# Out:
#              Fare
#              mean       max  min
# Pclass
# 1       84.154687  512.3292  0.0
# 2       20.662183   73.5000  0.0
# 3       13.707707   69.5500  0.0

# %%
# class task
# find the passengers with the max and min fare from each class
df[df['Fare'] == 512.3292]
# Out:
#                                   Name  Survived  Pclass     Sex   Age  SibSp  \
# 257                    Miss. Anna Ward         1       1  female  35.0      0
# 676  Mr. Thomas Drake Martinez Cardeza         1       1    male  36.0      0
# 733              Mr. Gustave J Lesurer         1       1    male  35.0      0
#
#      PaCh      Fare
# 257     0  512.3292
# 676     1  512.3292
# 733     0  512.3292

# %%
df[df['Fare'] == 73.5000]
# Out:
#                            Name  Survived  Pclass   Sex   Age  SibSp  PaCh  \
# 71          Mr. Ambrose Jr Hood         0       2  male  21.0      0     0
# 119  Mr. Stanley George Hickman         0       2  male  21.0      2     0
# 383    Mr. Charles Henry Davies         0       2  male  18.0      0     0
# 652    Mr. Leonard Mark Hickman         0       2  male  24.0      2     0
# 662           Mr. Lewis Hickman         0       2  male  32.0      2     0
#
#      Fare
# 71   73.5
# 119  73.5
# 383  73.5
# 652  73.5
# 662  73.5

# %%
df[df['Fare'] == 69.5500]
# Out:
#                             Name  Survived  Pclass     Sex   Age  SibSp  PaCh  \
# 158    Master. Thomas Henry Sage         0       3    male   5.0      8     2
# 179  Miss. Constance Gladys Sage         0       3  female   8.0      8     2
# 200           Mr. Frederick Sage         0       3    male  17.0      8     2
# 322      Mr. George John Jr Sage         0       3    male  20.0      8     2
# 788       Miss. Stella Anna Sage         0       3  female  21.0      8     2
# 842      Mr. Douglas Bullen Sage         0       3    male  18.0      8     2
# 859     Miss. Dorothy Edith Sage         0       3  female  14.0      8     2
#
#       Fare
# 158  69.55
# 179  69.55
# 200  69.55
# 322  69.55
# 788  69.55
# 842  69.55
# 859  69.55

# %%
# Simple condition
df[df['Fare'] == 0.0]
# Out:
#                                Name  Survived  Pclass   Sex   Age  SibSp  \
# 178              Mr. Lionel Leonard         0       3  male  36.0      0
# 261            Mr. William Harrison         0       1  male  40.0      0
# 269     Mr. William Henry Tornquist         1       3  male  25.0      0
# 275              Mr. Francis Parkes         0       2  male  21.0      0
# 300  Mr. William Cahoone Jr Johnson         0       3  male  19.0      0
# 411   Mr. Alfred Fleming Cunningham         0       2  male  22.0      0
# 463            Mr. William Campbell         0       2  male  21.0      0
# 478          Mr. Anthony Wood Frost         0       2  male  37.0      0
# 594              Mr. Alfred Johnson         0       3  male  49.0      0
# 630    Mr. William Henry Marsh Parr         0       1  male  30.0      0
# 671       Mr. Ennis Hastings Watson         0       2  male  19.0      0
# 728             Mr. Robert J Knight         0       2  male  41.0      0
# ...

# %% [markdown]
# ## Renaming Columns and Indexes

# %%
# Renaming columns
# Use the rename() method with columns parameter:
df.rename(columns={'Name': 'FullName'}, inplace=True)

# %%
df
# Out:
#                                               FullName  Survived  Pclass  \
# 0                               Mr. Owen Harris Braund         0       3
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...         1       1
# 2                                Miss. Laina Heikkinen         1       3
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle         1       1
# 4                              Mr. William Henry Allen         0       3
# ..                                                 ...       ...     ...
# 882                               Rev. Juozas Montvila         0       2
# 883                        Miss. Margaret Edith Graham         1       1
# 884                     Miss. Catherine Helen Johnston         0       3
# 885                               Mr. Karl Howell Behr         1       1
# 886                                 Mr. Patrick Dooley         0       3
#
#         Sex   Age  SibSp  PaCh     Fare
# 0      male  22.0      1     0   7.2500
# ...

# %%
# Renaming all columns at once
# df.columns = ['Full Name', 'Years Old']
# Make sure the number of values here match the number of columns

# %%
# Renaming index (row labels)

# I've hardly had to rename indexes
df.rename(index={0: 'First', 1: 'Second'}, inplace=True)
df.head()
# Notice the column order changes
# Out:
#                                                  FullName  Survived  Pclass  \
# First                              Mr. Owen Harris Braund         0       3
# Second  Mrs. John Bradley (Florence Briggs Thayer) Cum...         1       1
# 2                                   Miss. Laina Heikkinen         1       3
# 3             Mrs. Jacques Heath (Lily May Peel) Futrelle         1       1
# 4                                 Mr. William Henry Allen         0       3
#
#            Sex   Age  SibSp  PaCh     Fare
# First     male  22.0      1     0   7.2500
# Second  female  38.0      1     0  71.2833
# 2       female  26.0      0     0   7.9250
# 3       female  35.0      1     0  53.1000
# 4         male  35.0      0     0   8.0500

# %%
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                                             FullName  Survived  Pclass  \
# 0                             Mr. Owen Harris Braund         0       3
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...         1       1
# 2                              Miss. Laina Heikkinen         1       3
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle         1       1
# 4                            Mr. William Henry Allen         0       3
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  26.0      0     0   7.9250
# 3  female  35.0      1     0  53.1000
# 4    male  35.0      0     0   8.0500

# %%
# Run this if you did the above (else, leave it)
df.drop(columns=['index'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 2
#       1 # Run this if you did the above (else, leave it)
# ----> 2 df.drop(columns=['index'], inplace=True)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
# ...

# %% [markdown]
# ## Adding Columns and Rows

# %%
# had to import the data again to reset, but this isn't
df = pd.read_csv('data/titanic.csv')
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  26.0      0     0   7.9250
# 3  female  35.0      1     0  53.1000
# 4    male  35.0      0     0   8.0500

# %%
# Adding a new column (with default or calculated values)
df['Status'] = 'Poor'

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare Status
# 0    male  22.0      1     0   7.2500   Poor
# 1  female  38.0      1     0  71.2833   Poor
# 2  female  26.0      0     0   7.9250   Poor
# 3  female  35.0      1     0  53.1000   Poor
# 4    male  35.0      0     0   8.0500   Poor

# %%
# fill the column based of certain condition
df.loc[df['Fare'] > 10, 'Status'] = 'Rich'

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare Status
# 0    male  22.0      1     0   7.2500   Poor
# 1  female  38.0      1     0  71.2833   Rich
# 2  female  26.0      0     0   7.9250   Poor
# 3  female  35.0      1     0  53.1000   Rich
# 4    male  35.0      0     0   8.0500   Poor

# %%
# fill the column based of certain condition
df.loc[df['Fare'] > 20, 'Status'] = 'Rich'     #

# %%
df.tail()
# Out:
#      Survived  Pclass                            Name     Sex   Age  SibSp  \
# 882         0       2            Rev. Juozas Montvila    male  27.0      0
# 883         1       1     Miss. Margaret Edith Graham  female  19.0      0
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0      1
# 885         1       1            Mr. Karl Howell Behr    male  26.0      0
# 886         0       3              Mr. Patrick Dooley    male  32.0      0
#
#      PaCh   Fare Status
# 882     0  13.00   Rich
# 883     0  30.00   Rich
# 884     2  23.45   Rich
# 885     0  30.00   Rich
# 886     0   7.75   Poor

# %%
# You can also use np.where to get the same result
import numpy as np
df['Status'] = np.where(df['Fare'] < 10, 'Poor', np.where(df['Fare'] < 50, 'Avg_rich', 'Rich'))

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  SibSp  PaCh     Fare Status
# ...

# %%
df.w
pd.w

# %%
#Inserting at a specific position
# Insert at column position 1
df.insert(1, 'ID', 101)

# %%
df.head()
# Out:
#    Survived   ID  Pclass                                               Name  \
# 0         0  101       3                             Mr. Owen Harris Braund
# 1         1  101       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1  101       3                              Miss. Laina Heikkinen
# 3         1  101       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0  101       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare Status
# 0    male  22.0      1     0   7.2500   Poor
# 1  female  38.0      1     0  71.2833   Rich
# 2  female  26.0      0     0   7.9250   Poor
# 3  female  35.0      1     0  53.1000   Rich
# 4    male  35.0      0     0   8.0500   Poor

# %%
# Adding a row using loc (if index doesn’t exist)
# Add a new row at index 2
df.loc[2] = [1, 101, 1, 'Tomi Jesu', 'female', 22, 1, 0, 15.0, 'Rich']
df.head()
# Out:
#    Survived   ID  Pclass                                               Name  \
# 0         0  101       3                             Mr. Owen Harris Braund
# 1         1  101       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1  101       1                                          Tomi Jesu
# 3         1  101       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0  101       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare Status
# 0    male  22.0      1     0   7.2500   Poor
# 1  female  38.0      1     0  71.2833   Rich
# 2  female  22.0      1     0  15.0000   Rich
# 3  female  35.0      1     0  53.1000   Rich
# 4    male  35.0      0     0   8.0500   Poor

# %%
# to add at the buttom you can also use concat (use pd.concat),
# before now, you could use append()

new_row = pd.DataFrame([[1, 101, 2, 'Funmi Ajagun.', 'female', 25, 1, 0, 15.0, 'Rich']], columns=df.columns)
new_row
# Out:
#    Survived   ID  Pclass           Name     Sex  Age  SibSp  PaCh  Fare Status
# 0         1  101       2  Funmi Ajagun.  female   25      1     0  15.0   Rich

# %%
df = pd.concat([df, new_row], ignore_index=True)

# %%
df.tail()
# Out:
#      Survived   ID  Pclass                            Name     Sex   Age  \
# 883         1  101       1     Miss. Margaret Edith Graham  female  19.0
# 884         0  101       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1  101       1            Mr. Karl Howell Behr    male  26.0
# 886         0  101       3              Mr. Patrick Dooley    male  32.0
# 887         1  101       2                   Funmi Ajagun.  female  25.0
#
#      SibSp  PaCh   Fare Status
# 883      0     0  30.00   Rich
# 884      1     2  23.45   Rich
# 885      0     0  30.00   Rich
# 886      0     0   7.75   Poor
# 887      1     0  15.00   Rich

# %%
# Dropping columns
df.drop(columns=['ID'], inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       1                                          Tomi Jesu
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare Status
# 0    male  22.0      1     0   7.2500   Poor
# 1  female  38.0      1     0  71.2833   Rich
# 2  female  22.0      1     0  15.0000   Rich
# 3  female  35.0      1     0  53.1000   Rich
# 4    male  35.0      0     0   8.0500   Poor

# %%
# Dropping using axis argument
# Drop column
df.drop('Status', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       1                                          Tomi Jesu
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  22.0      1     0  15.0000
# 3  female  35.0      1     0  53.1000
# 4    male  35.0      0     0   8.0500

# %%
# Drop row
df.drop(1, axis=0, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                         Name     Sex  \
# 0         0       3                       Mr. Owen Harris Braund    male
# 2         1       1                                    Tomi Jesu  female
# 3         1       1  Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 4         0       3                      Mr. William Henry Allen    male
# 5         0       3                              Mr. James Moran    male
#
#     Age  SibSp  PaCh     Fare
# 0  22.0      1     0   7.2500
# 2  22.0      1     0  15.0000
# 3  35.0      1     0  53.1000
# 4  35.0      0     0   8.0500
# 5  27.0      0     0   8.4583

# %% [markdown]
# # How to save you dataframe

# %%
# take note to always drop the default pandas index (this is always added by default)
# secondly, you can also save to other file formats

# %%
df.to_csv('data/new_titanic.csv', index=False)

# %%
new_df = pd.read_csv('data/new_titanic.csv')
new_df
# Out:
#      Survived  Pclass                                         Name     Sex  \
# 0           0       3                       Mr. Owen Harris Braund    male
# 1           1       1                                    Tomi Jesu  female
# 2           1       1  Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 3           0       3                      Mr. William Henry Allen    male
# 4           0       3                              Mr. James Moran    male
# ..        ...     ...                                          ...     ...
# 882         1       1                  Miss. Margaret Edith Graham  female
# 883         0       3               Miss. Catherine Helen Johnston  female
# 884         1       1                         Mr. Karl Howell Behr    male
# 885         0       3                           Mr. Patrick Dooley    male
# 886         1       2                                Funmi Ajagun.  female
#
#       Age  SibSp  PaCh     Fare
# 0    22.0      1     0   7.2500
# ...

# %% [markdown]
# ## Pandas Data Inspection & Cleaning

# %% [markdown]
# For this section:
# The data set contains some empty cells ("Date" in row 22, and "Calories" in row 18
# and 28).
# The data set contains wrong format ("Date" in row 26).
# The data set contains wrong data ("Duration" in row 7).
# The data set contains duplicates (row 11 and 12).

# %%
df = pd.read_csv('data/dirty_data.csv')

df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# Handling Missing Data
# first, we need to identify missing values
# This function:
# Returns a new table of the exact same size as the original (don't do th
# Fills every spot with True if the value is missing (like NaN or None).
# Fills the spot with False if the value is present and valid
# Boolean DataFrame

df.isna() # or df.isnull()

# opposite is df.notna() or df.notnull() # To get True
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
# return only missing ones

df.loc[df.isna().any(axis=1), df.isna() .any(axis=0)]
# Out:
#             Date  Calories
# 18  '2020/12/18'       NaN
# 22           NaN     282.0
# 28  '2020/12/28'       NaN

# %%
df.isna().any   #
# Out:
# Duration    False
# Date         True
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
df.isna().all()  # check fo howmany rows
# Out:
# Duration    False
# Date        False
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
# to just return the count of NaNs per column
df.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# ## How to handle missing data                     2/09/26

# %% [markdown]
# 1. Dropping Missing Data (dropna): If the missing data is
# minimal (e.g., less than 5% of your dataset), you can remove
# it using df.dropna()

# %%
# Drop missing values
# Drop rows with any NaNs
# Take note of the axis=0, how='any arguments

df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  29 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     29 non-null     int64
#  3   Maxpulse  29 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df = pd.read_csv('data/dirty_data.csv')

# %%
# Drop rows where all values are NaN
df.dropna(how='all', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# you can choose to drop from a particular row by using subset (just use a list)
# Drop rows where 'Date' is NaN

df.dropna(subset=['Date'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.5+ KB

# %%
# Lastly, you can drop entire column
# Remove any column containing missing data.python
# We hardly do this in practice
# df.dropna(axis=1)

# %%
# We also have threshold (thresh):
# Keeps rows/columns only if they contain at least N non-null values.

df.dropna(thresh=3)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
Filling Missing Data (fillna): When you cannot afford to lose
data, you can replace missing cells with alternative values
using df.fillna()

# %%
df = pd.read_csv('data/dirty_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# Constant value substitution: Fills every missing cell with a specific n
# Fill all NaNs with 0
# But this might not be suitable in all cases
df.fillna(0, inplace=True)

# %%
# Fill with a default string (not really useful too)
# df['Calories'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df = pd.read_csv('data/dirty_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# Statitical Imputation (Numerical columns):
# Replaces missing data with the column's mean, median, or mode.
# df['Calories'].fillna(df['Calories'].mean(), inplace=True) # old way
df['Calories'] = df['Calories'].fillna(df['Calories'].mean())

# %%
df.isna() .sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.loc[df.isna().any(axis=1), df.isna().any(axis=0)]
# Out:
#             Date  Calories
# 18  '2020/12/18'       NaN
# 22           NaN     282.0
# 28  '2020/12/28'       NaN

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
# Setting keep=False ensures all occurrences of the duplicate rows are ma
df.loc[df.duplicated(keep=False), :]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7

# %%
# Drop duplicates

# Keep first by default
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
# Keep last occurrence
df.drop_duplicates(keep='last')
# I didn't actually run them on this
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %% [markdown]
# ## Data Type Conversion

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.5+ KB

# %%
# Our maxpulse is int, let's change it to float
df['Maxpulse'] = df['Maxpulse'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     float64
#  4   Calories  29 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.5+ KB

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110     130.0     409.1
# 1        60  '2020/12/02'    117     145.0     479.0
# 2        60  '2020/12/03'    103     135.0     340.0
# 3        45  '2020/12/04'    109     175.0     282.4
# 4        45  '2020/12/05'    117     148.0     406.0

# %% [markdown]
# ## String Manipulation Using .str

# %%
df = pd.read_csv('data/titanic.csv')
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  SibSp  PaCh     Fare
# 0    male  22.0      1     0   7.2500
# 1  female  38.0      1     0  71.2833
# 2  female  26.0      0     0   7.9250
# 3  female  35.0      1     0  53.1000
# 4    male  35.0      0     0   8.0500

# %%
# Using our first dataset
df['Name'].str.lower() # all lowercase
# If i wanted to return an updated df
# df["Name"] = df["Name"].str.lower()
# Out:
# 0                                 mr. owen harris braund
# 1      mrs. john bradley (florence briggs thayer) cum...
# 2                                  miss. laina heikkinen
# 3            mrs. jacques heath (lily may peel) futrelle
# 4                                mr. william henry allen
#                              ...
# 882                                 rev. juozas montvila
# 883                          miss. margaret edith graham
# 884                       miss. catherine helen johnston
# 885                                 mr. karl howell behr
# 886                                   mr. patrick dooley
# Name: Name, Length: 887, dtype: object

# %%
# explore on your own
df['Name'].str.upper() # all uppercase
df['Name'].str.title() # title case
df['Name'].str.strip() # remove whitespace
df['Name'].str.replace(' ', '_') # replace space with underscore

# %% [markdown]
# # Combining DataFrames

# %%
# a. concat(): Combine along rows or columns
data1 = {
'Name': ['Rhoda', 'Jemilah', 'Rahmat', 'Esther'],
'Age': [25, 30, 35, 10],
'City': ['Ilorin', 'Lagos', 'Ibadan', 'Abuja']
}
df1 = pd.DataFrame(data1)
df1
# Out:
#       Name  Age    City
# 0    Rhoda   25  Ilorin
# 1  Jemilah   30   Lagos
# 2   Rahmat   35  Ibadan
# 3   Esther   10   Abuja

# %%
data2 = {
'Name': ['Abiola', 'Nofisat', 'Salamat', 'Lola'],
'Age': [20, 20, 35, 11],
'City': ['Abuja', 'Akure', 'Mina', 'Kano']
}
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age   City
# 0   Abiola   20  Abuja
# 1  Nofisat   20  Akure
# 2  Salamat   35   Mina
# 3     Lola   11   Kano

# %%
# Stack rows
# remember the concat we did earlier?
# remeber to ignore index
pd.concat([df1, df2], axis=0, ignore_index=True)
# Out:
#       Name  Age    City
# 0    Rhoda   25  Ilorin
# 1  Jemilah   30   Lagos
# 2   Rahmat   35  Ibadan
# 3   Esther   10   Abuja
# 4   Abiola   20   Abuja
# 5  Nofisat   20   Akure
# 6  Salamat   35    Mina
# 7     Lola   11    Kano

# %%
# Side-by-side
# we don't need to ignore index here
pd.concat([df1, df2], axis=1)
# Out:
#       Name  Age    City     Name  Age   City
# 0    Rhoda   25  Ilorin   Abiola   20  Abuja
# 1  Jemilah   30   Lagos  Nofisat   20  Akure
# 2   Rahmat   35  Ibadan  Salamat   35   Mina
# 3   Esther   10   Abuja     Lola   11   Kano

# %%
# merge(): SQL-style joins on columns
# Inner join by default

pd.merge(df1, df2, on='Age')

# combines df1 and df2 side-by-side by matching rows that share the same value
# Includes only matching keys from both DataFrames. Rows with keys that don't
# Out:
#    Name_x  Age  City_x   Name_y City_y
# 0  Rahmat   35  Ibadan  Salamat   Mina
